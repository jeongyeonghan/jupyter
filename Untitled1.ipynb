# %%
list1=[10,20]
list2=[30,40]

# %%
list1+list2
# Out:
# [10, 20, 30, 40]

# %%
list1*2
# Out:
# [10, 20, 10, 20]

# %%
list1-1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b4e49dbc2005> in <module>
# ----> 1 list1-1
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'
